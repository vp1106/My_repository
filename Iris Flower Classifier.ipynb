# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report ,accuracy_score

# %%
#importing dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
column_names=["sepal_length", "sepal_width","petal_length", "petal_width", "class"]
iris_data=pd.read_csv(url,names=column_names)

# %%
iris_data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
type(iris_data)
# Out:
# pandas.core.frame.DataFrame

# %%
iris_data.iloc[50:]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [100 rows x 5 columns]

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(iris_data, hue="class")
plt.show()

#4 features 4*4 plots-pair plot feature
#each feature against 3 other features -3 scatter plots and 1 KDE(Kernel density plots)

# %%
#inferences from the plots
#petal length differentiates the three types better
#independent variable-all four
#class of th flower is the dependent variable

# %%
X=iris_data.drop("class", axis=1)#dropping the last column class from the table
X
y=iris_data["class"]
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object

# %%
X_train, X_test, y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 81            5.5          2.4           3.7          1.0
# 133           6.3          2.8           5.1          1.5
# 137           6.4          3.1           5.5          1.8
# 75            6.6          3.0           4.4          1.4
# 109           7.2          3.6           6.1          2.5
# ..            ...          ...           ...          ...
# 71            6.1          2.8           4.0          1.3
# 106           4.9          2.5           4.5          1.7
# 14            5.8          4.0           1.2          0.2
# 92            5.8          2.6           4.0          1.2
# 102           7.1          3.0           5.9          2.1
#
# [105 rows x 4 columns]

# %%
knn=KNeighborsClassifier(n_neighbors=3)
#3 classes so optimal would be -else over smoothinng
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred= knn.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test,y_pred))#predicted values are same the actual values
# Out:
# Accuracy: 1.0

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %%
X_test.head(2)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 73           6.1          2.8           4.7          1.2
# 18           5.7          3.8           1.7          0.3

# %%
new_data = pd.DataFrame({"sepal_length":[2.7],"sepal_width":4.5,"petal_length":1.4,"petal_width":2.9})

# %%
prediction = knn.predict(new_data)

# %%
prediction[0]
# Out:
# 'Iris-setosa'

# %%
iris_data.iloc[80:]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 80            5.5          2.4           3.8          1.1  Iris-versicolor
# 81            5.5          2.4           3.7          1.0  Iris-versicolor
# 82            5.8          2.7           3.9          1.2  Iris-versicolor
# 83            6.0          2.7           5.1          1.6  Iris-versicolor
# 84            5.4          3.0           4.5          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [70 rows x 5 columns]
